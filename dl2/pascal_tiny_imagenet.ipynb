# %% [markdown]
# ## Lesson8 pascal object detecion applied to Tiny ImageNet Visual Recognition Challenge
# https://tiny-imagenet.herokuapp.com/
#
# "*Tiny Imagenet has 200 classes. Each class has 500 training images, 50 validation images, and 50 test images. We have released the training and validation sets with images and annotations. We provide both class labels and bounding boxes as annotations; however, you are asked only to predict the class label of each image without localizing the objects. The test set is released without labels*"
#
# see also Tiny Imagenet Challenge, Yinbin Ma (year?) for a paper on using this dataset

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from IPython.core.debugger import set_trace

from os import listdir
from os.path import isfile, join
import csv

from pathlib import Path
import json
from matplotlib import patches, patheffects
from scipy.special import expit

from fastai.conv_learner import *
from fastai.dataset import *

# %%
#for pycharm notebooks
plt.ion()

# %%
PATH = Path('/mnt/samsung_1tb/Data/fastai/tiny-imagenet/tiny_imagenet_restructured/')

# %%
os.listdir(PATH)
# Out:
# ['test',
#  'models',
#  'words.txt',
#  'yukez.txt',
#  'readme.txt',
#  'train',
#  'val',
#  'tmp',
#  'wnids.txt']

# %% [markdown]
# Stage 1: re-structure the data layout and file structures
#
#     JPEGS: all images in one directory
#     find . -name \*.JPEG -exec cp {} /path/tiny_imagenet_restructured/train/JPEGImages/ \;
#     find . -name \*boxes.txt -exec cp {} /path/tiny_imagenet_restructured/train/Boxes/ \;
#     CSV: create df of filename, category
#
# Stage 2: read the data in to pascal.ipynb-like dicts
#
# ie we want
#
#     trn_anno: trn_anno[o[IMG_ID]].append((bb,o[CAT_ID]))
#     #trn_anno is a dict of {id, [(bbox, category_id), ...]} where coords are TL, BR numpy consistent x,y coords
#
#     cats = dict((o[ID], o['name']) for o in trn_j[CATEGORIES])
#     trn_fns = dict((o[ID], o[FILE_NAME]) for o in trn_j[IMAGES])
#     trn_ids = [o[ID] for o in trn_j[IMAGES]]

# %%
JPEGS = 'train/JPEGImages'
IMG_PATH = PATH/JPEGS

# %%
df_submission_example  = pd.read_csv(PATH/'yukez.txt', names=['file_name', 'code'], delim_whitespace=True)

# %%
df_submission_example.head(n=2)
# Out:
#      file_name       code
# 0  test_0.JPEG  n04067472
# 1  test_1.JPEG  n02788148

# %%
code_words = {}

with open(PATH/'words.txt') as f:
  for row in csv.reader(f, delimiter="\t"):
    #We keep only the first of the descriptions
    code = row[1].split(",")[0]
    #replace whitespaces with underscore
    code = "_".join(code.split()).strip().lower()
    code_words[row[0]] = code

# %%
wnids = [line.strip() for line in open(PATH/'wnids.txt', 'r')]
#eg ['n02124075', 'n04067472', 'n04540053',...]

# %%
#keep only those words from our images
code_words = {k: code_words[k] for k in wnids}
#eg {'n01443537': 'goldfish', 'n01629819': 'European fire salamander',...
#code_words

# %%
cats = dict(enumerate(x for x in code_words.values()))
#cats eg {0: 'Egyptian cat', 1: 'reel',...

# %%
fn_bbox = {}
txt_files = [i for i in os.listdir(PATH/'train/Boxes/') if os.path.splitext(i)[1] == '.txt']

for f in txt_files:
    with open(os.path.join(PATH/'train/Boxes/',f)) as file_object:
        for row in csv.reader(file_object, delimiter="\t"):
            fn_bbox[row[0]] = row[1]+' '+row[2]+' '+row[3]+' '+row[4]

# %%
#note there is only a single bounding box per image
#ie {'n02837789_0.JPEG': '8 8 40 63', 'n02837789_1.JPEG': '32 24 54 39',...
#fn_bbox

# %%
file_id_df = pd.DataFrame({'file_id':wnids})
file_id_df.head(n=2)
# Out:
#      file_id
# 0  n02124075
# 1  n04067472

# %%
jpeg_filenames = [f for f in listdir(IMG_PATH) if isfile(join(IMG_PATH, f))]
jpeg_filenames.sort()
jpeg_fn_df = pd.DataFrame(jpeg_filenames)
trn_fns = list(jpeg_fn_df.to_dict().values())[0]
#eg {0: 'n01443537_0.JPEG', 1: 'n01443537_1.JPEG',...

# %%
#so we can look up by value
inv_trn_fns = {v: k for k, v in trn_fns.items()}
inv_cats = {v: k for k, v in cats.items()}
trn_anno = collections.defaultdict(lambda:[])
for k, v in fn_bbox.items():
    core_code = k.split('_')[0]
    bb = fn_bbox[k].split()
    bb = np.array([bb[0], bb[1], bb[2], bb[3]])
    bb = bb.astype(np.int16)
    cat_id = inv_cats[code_words[core_code]]
    trn_anno[inv_trn_fns[k]].append((bb, cat_id))
#trn_anno
im_a = trn_anno[37000]; im_a
# Out:
# [(array([ 8,  8, 40, 63], dtype=int16), 142)]

# %%
#conversion between numpy style and cs style
def bb_hw(a): 
    return np.array([a[1],a[0],a[3]-a[1],a[2]-a[0]])

# %%
im = open_image(IMG_PATH/trn_fns[0])

# %%
def show_img(im, figsize=None, ax=None):
    if not ax: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(im)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    return ax

# %%
def draw_outline(o, lw):
    o.set_path_effects([patheffects.Stroke(
        linewidth=lw, foreground='black'), patheffects.Normal()])

# %%
def draw_rect(ax, b):
    patch = ax.add_patch(patches.Rectangle(b[:2], *b[-2:], fill=False, edgecolor='white', lw=2))
    draw_outline(patch, 4)

# %%
def draw_text(ax, xy, txt, sz=14):
    text = ax.text(*xy, txt,
        verticalalignment='top', color='white', fontsize=sz, weight='bold')
    draw_outline(text, 1)

# %%
def draw_im(im, ann):
    ax = show_img(im, figsize=(16,8))
    for b,c in ann:
        b = bb_hw(b)
        draw_rect(ax, b)
        draw_text(ax, b[:2], cats[c], sz=16)

# %%
def draw_idx(i):
    im_a = trn_anno[i]
    im = open_image(IMG_PATH/trn_fns[i])
    print(im.shape)
    draw_im(im, im_a)

# %%
def get_lrg(b):
    if not b: 
        raise Exception()
    b = sorted(b, key=lambda x: np.product(x[0][-2:]-x[0][:2]), reverse=True)
    return b[0]

# %%
#not necessary as only 1 bbox per image, TODO remove this call
trn_lrg_anno = {a: get_lrg(b) for a,b in trn_anno.items()}

# %%
b,c = trn_lrg_anno[0]
#b = bb_hw(b)
ax = show_img(open_image(IMG_PATH/trn_fns[0]), figsize=(5,10))
draw_rect(ax, b)
draw_text(ax, b[:2], cats[c], sz=16)
plt.show()

# %%
b,c = trn_lrg_anno[25001]
#b = bb_hw(b)
ax = show_img(open_image(IMG_PATH/trn_fns[25001]), figsize=(5,10))
draw_rect(ax, b)
draw_text(ax, b[:2], cats[c], sz=16)
plt.show()

# %%
b
# Out:
# array([ 4,  6, 61, 61], dtype=int16)

# %%
#create filename, category CSV
(PATH/'tmp').mkdir(exist_ok=True)
CSV = PATH/'tmp/lrg.csv'

# %%
fn_cat_dict = {}
for k, v in trn_fns.items():
    core_code = v.split('_')[0]
    cat = code_words[core_code]
    fn_cat_dict[v] = cat

# %%
df = pd.DataFrame(list(fn_cat_dict.items()), columns=['filename', 'category'])
df.head(n=2)
df.to_csv(CSV, index=False)

# %%
df.head(n=2)
# Out:
#            filename  category
# 0  n01443537_0.JPEG  goldfish
# 1  n01443537_1.JPEG  goldfish

# %%
#data check
for item in trn_fns:
    if item not in df['filename']:
        print(f'{item}')

# %% [markdown]
# ### Architecture

# %%
#get av size of first 100 images
image_list = list(trn_fns.values())
widths = []
heights = []
for im in image_list[:100]:
    w,h=Image.open(IMG_PATH/im).size
    widths.append(w)
    heights.append(h)
av_w = sum(widths)/len(widths)
av_h = sum(heights)/len(heights)
print(f'avg width: {av_w}, avg height: {av_h}, max w: {max(widths)}, min w: {min(widths)}, max h: {max(heights)}, min h: {min(heights)}')
# Out:
# avg width: 64.0, avg height: 64.0, max w: 64, min w: 64, max h: 64, min h: 64

# %%
f_model = resnet34
size = 64
bs = 64

# %%
transforms = tfms_from_model(f_model, sz = size, aug_tfms=transforms_side_on, crop_type = CropType.NO)
model_data = ImageClassifierData.from_csv(PATH, JPEGS, CSV, tfms=transforms)

# %%
x,y = next(iter(model_data.val_dl))
show_img(model_data.val_ds.denorm(to_np(x))[0])

# %%
#on first pass y values in data.val_dl.dataset (in model.fit() vals = validate(stepper, data.val_dl, metrics)) were arrays of floats (0.0) instead of integers
#problem was with is_single = np.all(label_arr.sum(axis=1)==1), I re-parsed the labels joining words by underscore and converting to lowercase which fixed this issue

# %%
learn = ConvLearner.pretrained(f_model, model_data, metrics=[accuracy])
learn.opt_fn = optim.Adam

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  68%|██████▊   | 849/1250 [00:25<00:12, 32.83it/s, loss=13.8]

# %%
learn.sched.plot()

# %%
lr = 1e-3

# %%
learn.fit(lrs=lr, n_cycle=1, cycle_len=3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
#   9%|▊         | 108/1250 [00:03<00:38, 29.76it/s, loss=5.94]
#   9%|▉         | 114/1250 [00:03<00:38, 29.80it/s, loss=5.93]
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_monitor.py", line 63, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# epoch      trn_loss   val_loss   accuracy
#     0      2.773672   2.412915   0.417981
#     1      2.557769   2.270932   0.451228
#     2      2.414521   2.243581   0.458167
# [2.2435813, 0.4581669329073482]

# %%
learn.sched.plot_lr()

# %%
lrs = np.array([lr/1000, lr/100, lr])

# %%
learn.freeze_to(-2)

# %%
lrf = learn.lr_find(lrs/1000)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  73%|███████▎  | 915/1250 [01:05<00:23, 14.05it/s, loss=12.1]

# %%
learn.fit(lrs=lrs/5, n_cycle=1, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   5%|▌         | 67/1250 [00:04<01:27, 13.45it/s, loss=3.27]
#   6%|▌         | 71/1250 [00:05<01:25, 13.75it/s, loss=3.27]
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_monitor.py", line 63, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# epoch      trn_loss   val_loss   accuracy
#     0      2.92328    2.584336   0.397314
# [2.584336, 0.39731429712460065]

# %%
learn.unfreeze()

# %%
learn.fit(lrs=lrs/5, n_cycle=1, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      2.766561   2.469612   0.416883
# [2.4696116, 0.4168829872204473]

# %%
learn.save('clas_one')

# %%
learn.load('clas_one')

# %%
x, y = next(iter(model_data.val_dl))
x[0]
# Out:
# (0 ,.,.) =
#   0.1083 -0.0287  0.0912  ...   0.5364 -0.0458  0.3652
#  -0.0629 -0.0801  0.1426  ...   1.1872  1.0502  0.3481
#  -0.0629 -0.0287  0.2453  ...   1.2728  1.2385  0.9474
#            ...             ⋱             ...
#  -0.4568 -0.4397 -0.4226  ...  -0.2684 -0.1314  0.6563
#  -0.4054 -0.4911 -0.4739  ...  -0.1486 -0.2171  0.1939
#  -0.4568 -0.5767 -0.5082  ...  -0.3883 -0.2684 -0.2342
#
# (1 ,.,.) =
#   1.2731  1.1331  1.1856  ...   1.7458  1.1856  1.6758
#   1.0980  1.0630  1.2381  ...   2.3761  2.3235  1.6758
#   1.0805  1.1155  1.3431  ...   2.4286  2.4286  2.2885
#            ...             ⋱             ...
#   0.2227  0.2402  0.2752  ...   0.5728  0.6779  1.4832
#   0.2752  0.1877  0.2227  ...   0.6954  0.6254  1.0455
#   0.2227  0.1001  0.1877  ...   0.4328  0.5553  0.5903
#
# (2 ,.,.) =
#   1.5594  1.4200  1.4897  ...   1.6814  1.2457  1.7337
#   1.3851  1.3502  1.5420  ...   2.2740  2.2914  1.6640
#   1.3677  1.4025  1.6814  ...   2.2566  2.3437  2.1346
#            ...             ⋱             ...
#   0.2522  0.2348  0.1999  ...   0.0256  0.0779  0.8797
#   0.2696  0.1476  0.1128  ...   0.2173  0.1476  0.5311
#   0.2173  0.0605  0.0779  ...   0.0431  0.1302  0.1651
# [torch.cuda.FloatTensor of size 3x64x64 (GPU 0)]

# %%
batch_preds = predict_batch(learn.model, x)

# %%
batch_preds
# Out:
# Variable containing:
# -7.7398e+00 -8.0422e+00 -3.1504e+00  ...  -7.6799e+00 -7.0643e+00 -7.3862e+00
# -1.6367e+01 -1.7347e+01 -1.6669e+01  ...  -1.4842e+01 -1.4647e+01 -1.3847e+01
# -6.6881e+00 -7.4408e+00 -3.2533e+00  ...  -4.8862e+00 -7.0846e+00 -6.5247e+00
#                 ...                   ⋱                   ...
# -1.5470e+01 -1.7175e+01 -1.5282e+01  ...  -1.1643e+01 -1.1478e+01 -1.7152e+01
# -1.4534e+01 -1.5348e+01 -1.4157e+01  ...  -1.5247e+01 -1.3872e+01 -1.2834e+01
# -6.7404e+00 -7.2673e+00 -1.0019e+01  ...  -8.1432e+00 -6.8544e+00 -8.6133e+00
# [torch.cuda.FloatTensor of size 64x200 (GPU 0)]

# %%
probs = F.softmax(batch_preds, -1)
probs
# Out:
# Variable containing:
#  4.3517e-04  3.2161e-04  4.2836e-02  ...   4.6202e-04  8.5506e-04  6.1978e-04
#  7.7966e-08  2.9262e-08  5.7634e-08  ...   3.5831e-07  4.3549e-07  9.6892e-07
#  1.2457e-03  5.8684e-04  3.8646e-02  ...   7.5500e-03  8.3792e-04  1.4668e-03
#                 ...                   ⋱                   ...
#  1.9126e-07  3.4764e-08  2.3063e-07  ...   8.7804e-06  1.0353e-05  3.5564e-08
#  4.8731e-07  2.1593e-07  7.1040e-07  ...   2.3900e-07  9.4502e-07  2.6695e-06
#  1.1822e-03  6.9797e-04  4.4541e-05  ...   2.9070e-04  1.0549e-03  1.8168e-04
# [torch.cuda.FloatTensor of size 64x200 (GPU 0)]

# %%
x = to_np(x)
preds = to_np(probs)

# %%
preds = np.argmax(preds, -1)

# %%
#draw the predictions
fig, axes = plt.subplots(3, 4, figsize = (12, 8))
for i,ax in enumerate(axes.flat):
    ima=model_data.val_ds.denorm(x)[i]
    b = model_data.classes[preds[i]]
    ax = show_img(ima, ax=ax)
    draw_text(ax, (0, 0), b)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bbox Only

# %%
#create a model data object for bboxes
#create a model data object for classses
#combine these into one model

# %%
trn_ids = list(trn_fns.keys())
BB_CSV = PATH/'tmp/bb.csv'

# %%
bb = np.array([trn_lrg_anno[o][0] for o in trn_ids])
#want space sep data
bbs = [' '.join(str(p) for p in o) for o in bb]

df = pd.DataFrame({'fn': [trn_fns[o] for o in trn_ids], 'bbox': bbs}, columns=['fn', 'bbox'])
df.to_csv(BB_CSV, index=False)

# %%
BB_CSV.open().readlines()[:5]
# Out:
# ['fn,bbox\n',
#  'n01443537_0.JPEG,0 10 63 58\n',
#  'n01443537_1.JPEG,14 2 54 49\n',
#  'n01443537_10.JPEG,1 17 58 56\n',
#  'n01443537_100.JPEG,5 12 63 56\n']

# %%
#define architecture
f_model = resnet34
sz = 64
bs = 64

# %%
#lighting is image-average*b + c
augs = [RandomFlip(), RandomRotate(20), RandomLighting(b=0.1, c=0.1)]
augs
# Out:
# [<fastai.transforms.RandomFlip at 0x7f705154e588>,
#  <fastai.transforms.RandomRotate at 0x7f705154e240>,
#  <fastai.transforms.RandomLighting at 0x7f705154e470>]

# %%
tfms = tfms_from_model(f_model=f_model, sz=sz, aug_tfms=augs)
#classifiers are categorical, here doing regression
# if continuous=True then label_arr = np.array([np.array(csv_labels[i]).astype(np.float32) for i in fnames])
model_data = ImageClassifierData.from_csv(PATH, JPEGS, csv_fname=BB_CSV, bs=bs, tfms = tfms, continuous=True)

# %%
#draw images and bboxes - note problems with bbox locations - need to transform this in same way as indeprendant var
idx=3
fig, axes = plt.subplots(3, 3, figsize=(9,9))
for i, ax in enumerate(axes.flat):
    x,y = next(iter(model_data.aug_dl))
    ima = model_data.val_ds.denorm(to_np(x))[idx]
    #b = bb_hw(to_np(y[idx]))
    b = to_np(y[idx])
    print(f'b {b}')
    show_img(ima, ax=ax)
    draw_rect(ax, b)
# Out:
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]

# %%
augs = [RandomFlip(tfm_y=TfmType.COORD),
        RandomRotate(30, tfm_y=TfmType.COORD),
        #I havent set tfm_y for lighting - I assume wont have any impact
        RandomLighting(0.1,0.1)]

# %%
idx=3
fig, axes = plt.subplots(3, 3, figsize=(9,9))
for i, ax in enumerate(axes.flat):
    x,y = next(iter(model_data.aug_dl))
    ima = model_data.val_ds.denorm(to_np(x))[idx]
    b = to_np(y[idx])
    print(f'b {b}')
    show_img(ima, ax=ax)
    draw_rect(ax, b)
# Out:
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]
# b [23.  2. 48. 33.]

# %%
#now we create a model where we rotate 50% of the time 
tfm_y = TfmType.COORD
augs = [RandomFlip(tfm_y=tfm_y),
        #rotate up to 3% 50% of time
        RandomRotate(3, p=0.5, tfm_y=tfm_y),
        RandomLighting(0.05, 0.05, tfm_y=tfm_y)]

# %%
tfms = tfms_from_model(f_model, sz,aug_tfms=augs, crop_type=CropType.NO, tfm_y=tfm_y)
#path, folder, csv_fname, bs=64, tfms
model_data = ImageClassifierData.from_csv(PATH, JPEGS, BB_CSV, bs=bs, tfms=tfms, continuous=True)

# %%
#create a custom head. 4 bounding box coords
#Dont want to add standard fully connected layers that make up a classifier, want a single linear with 4 outputs
#flattens out, this is a simple final layer. 2048=512x2x2
head_reg4 = nn.Sequential(Flatten(), nn.Linear(in_features=2048, out_features=4))
#custom head wont create any of the fully connected network, wont add the adaptive average pooling, instead will add the model you specify
#note that f_model is resnet34
#stick this on a pretrained model
learn = ConvLearner.pretrained(f_model, data = model_data, custom_head=head_reg4)
learn.opt_fn = optim.Adam
#L1 Loss function minimizes the absolute differences between the estimated values and the target values
learn.crit = nn.L1Loss()

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 64, 64]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', False),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 32, 32]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 32, 32]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-11',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-12',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-13',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-14',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-15',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-16',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-17',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-18',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-24',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-25',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-26',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-27',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-28',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-29',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-30',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-34',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-35',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-36',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-37',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-38',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-39',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-40',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-41',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-42',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-43',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-44',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-45',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-46',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-47',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-48',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-49',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-50',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-51',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-52',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-53',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-54',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-55',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-56',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-57',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-58',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-59',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-60',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('Conv2d-61',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-62',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-63',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-64',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-65',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-66',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-67',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-68',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-69',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-70',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-71',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-72',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-73',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-75',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-76',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-77',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-78',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-79',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-80',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-81',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-82',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-83',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-84',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-85',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-86',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-87',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-88',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-89',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-90',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-91',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-92',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-93',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-94',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-95',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-96',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-97',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-98',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-99',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-100',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1179648)])),
#              ('BatchNorm2d-101',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-102',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-103',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-104',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('Conv2d-105',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-106',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-107',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-108',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-109',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-110',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-111',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-112',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-113',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-114',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-115',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-116',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-117',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-118',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-119',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-120',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-121',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-122',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Flatten-123',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 2048]),
#                            ('nb_params', 0)])),
#              ('Linear-124',
#               OrderedDict([('input_shape', [-1, 2048]),
#                            ('output_shape', [-1, 4]),
#                            ('trainable', True),
#                            ('nb_params', 8196)]))])

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  72%|███████▏  | 901/1250 [00:48<00:18, 18.50it/s, loss=37.1]

# %%
learn.sched.plot()

# %%
lr = 1e-4

# %%
learn.fit(lr, n_cycle=2, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
#   0%|          | 0/1250 [00:00<?, ?it/s]
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_monitor.py", line 63, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# epoch      trn_loss   val_loss
#     0      8.307075   8.416065
#     1      8.252816   8.380931
#     2      8.169926   8.222062
# [8.222062]

# %%
lrs = np.array([lr/100, lr/10, lr])
layer_groups = learn.get_layer_groups()

# %%
groups_freeze_to = layer_groups[-2:]

# %%
learn.freeze_to(-2)

# %%
learn.lr_find(lrs/1000)
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss
#     0      25.731592  22655.136719

# %%
learn.fit(lrs, 2, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss
#     0      7.09137    7.133624
#     1      7.081664   7.12456
#     2      6.609325   7.011669
# [7.0116687]

# %%
learn.freeze_to(-3)

# %%
learn.fit(lrs, 1, cycle_len=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=2), HTML(value='')))
# epoch      trn_loss   val_loss
#     0      6.830892   7.260717
#     1      6.357477   6.977545
# [6.9775453]

# %%
learn.save('reg4')
learn.load('reg4')

# %%
x, y = next(iter(model_data.val_dl))
learn.model.eval()
preds = to_np(learn.model(VV(x)))

# %%
fig, axes = plt.subplots(3,4, figsize=(12,8))
for i, ax in enumerate(axes.flat):
    ima = model_data.val_ds.denorm(to_np(x))[i]
    b = preds[i]
    ax = show_img(ima, ax=ax)
    draw_rect(ax, b)
plt.tight_layout()

# %% [markdown]
# ## Single object detection

# %%
trn_ids = list(trn_fns.keys())

# %%
BB_CSV = PATH/'tmp/bb.csv'

bb = np.array([trn_lrg_anno[o][0] for o in trn_ids])
#want space sep data
bbs = [' '.join(str(p) for p in o) for o in bb]

df = pd.DataFrame({'fn': [trn_fns[o] for o in trn_ids], 'bbox': bbs}, columns=['fn', 'bbox'])
df.to_csv(BB_CSV, index=False)

BB_CSV.open().readlines()[:5]
# Out:
# ['fn,bbox\n',
#  'n01443537_0.JPEG,0 10 63 58\n',
#  'n01443537_1.JPEG,14 2 54 49\n',
#  'n01443537_10.JPEG,1 17 58 56\n',
#  'n01443537_100.JPEG,5 12 63 56\n']

# %%
#bounding box and largest object
f_model = resnet34
sz = 64
bs = 64

# %%
val_idxs = get_cv_idxs(len(trn_fns))

# %%
augs = [RandomFlip(), RandomRotate(20), RandomLighting(b=0.1, c=0.1)]
tfms = tfms_from_model(f_model,sz=sz, aug_tfms=augs, crop_type=CropType.NO, tfm_y=TfmType.COORD)
#BB_CSV contains only filename, bbox coords
md = ImageClassifierData.from_csv(PATH, JPEGS, BB_CSV, bs=bs, tfms=tfms, continuous=True, val_idxs=val_idxs)
print(f'{type(md)}, size: {md.sz}')
# Out:
# <class 'fastai.dataset.ImageClassifierData'>, size: 64

# %%
tfms2 = tfms_from_model(f_model, sz=sz, aug_tfms=transforms_side_on, crop_type=CropType.NO)
#note we are reading in the CSV not BB_CSV, CSV contains only filename, category
md2 = ImageClassifierData.from_csv(PATH, JPEGS, CSV, bs=bs, tfms=tfms2)
md2.sz
# Out:
# 64

# %%
class ConcatLblDataset(Dataset):
    #take existing ds which has existing independent and dependant vars, add in dependent y2
    #extends torch Dataset, which requires one to override the methods below
    #sz property added as is required by learner (lean.summary())
    def __init__(self, ds, ds2):
        #I changed this to use seconds dataset rater than just y to help me understand this
        self.ds = ds
        self.ds2 = ds2
        
    def __len__(self):
        assert len(self.ds) == len(self.ds2)
        return len(self.ds)

    def __getitem__(self, i):
        x, y = self.ds[i]
        x2, y2 = self.ds2[i]
        #these should contain exactly the same info, so we only need to keep one. However this test fails
        #assert np.array_equal(x,x2)
        return (x, (y, y2))
    
    @property
    def sz(self):
        x, y = self.ds[0]
        print(f'sz: {x.shape[1]}')
        return x.shape[1]

# %%
#the bbox tagets
md.trn_ds.y
# Out:
# array([[ 0., 10., 63., 58.],
#        [14.,  2., 54., 49.],
#        [ 1., 17., 58., 56.],
#        ...,
#        [32., 21., 62., 57.],
#        [ 0.,  2., 63., 63.],
#        [16., 16., 51., 49.]], dtype=float32)

# %%
#classification dependent variable
md2.trn_ds.y
# Out:
# array([86, 86, 86, ...,  2,  2,  2])

# %%
#NB I changed the ConcatLblDataset. now it takes two datasets
trn_ds2 = ConcatLblDataset(md.trn_ds, md2.trn_ds)
val_ds2 = ConcatLblDataset(md.val_ds, md2.val_ds)

# %%
val_ds2[0][1]
# Out:
# (array([ 0., 11., 41., 48.], dtype=float32), 86)

# %%
md.trn_dl.dataset = trn_ds2
md.val_dl.dataset = val_ds2
print(f'{type(md)}')
# Out:
# <class 'fastai.dataset.ImageClassifierData'>

# %%
x, y = next(iter(md.val_dl))
idx=50
ima = md.val_ds.ds.denorm(to_np(x))[idx]
#b = bb_hw(to_np(y[0][idx])); b
b = to_np(y[0][idx]); b
# Out:
# array([37., 16., 59., 60.], dtype=float32)

# %%
ax = show_img(ima)
draw_rect(ax,b)
draw_text(ax, b[:2], md2.classes[y[1][idx]])
plt.show()

# %%
#replace head, add an extra linear layer and add dropout
head_reg4 = nn.Sequential(
    Flatten(), 
    nn.ReLU(),
    nn.Dropout(0.5),
    #this is a helper linear layer
    nn.Linear(in_features=512*2*2, out_features=256),
    nn.ReLU(),
    #1d as we have flattened 
    nn.BatchNorm1d(256),
    nn.Dropout(0.5),
    #note at this stage we only have 256 in_features
    nn.Linear(in_features=256, out_features= 4+len(cats))
)

# %%
#ConvnetBuilder(f, c, is_multi, is_reg, ps=None, xtra_fc=None, xtra_cut=0, custom_head=None)
model_arch = ConvnetBuilder(f=f_model, c=0, is_multi=False, is_reg=False, custom_head=head_reg4)

# %%
learn = ConvLearner(data = md, models = model_arch)

# %%
learn.opt_fn = optim.Adam

# %%
def detn_loss(input, target):
    bb_t, c_t = target
    #first dim is batch dim, input first 4, and 4 onwards elements
    bb_i, c_i = input[:, :4], input[:, 4:]
    #for bb_i we know they will be b/w 0 & 64
    #use sigmoid to force b/w 0&1 and force the range
    bb_i = F.sigmoid(bb_i)*64
    #scalar for classifications based on what works
    combined_loss = F.l1_loss(bb_i, bb_t) + F.cross_entropy(c_i, c_t)*20
    return combined_loss
    
def detn_l1(input, target):
    bb_t, _ = target
    bb_i = input[:, :4]
    bb_i = F.sigmoid(bb_i)*64
    f1_loss = F.l1_loss(V(bb_i), V(bb_t)).data
    return f1_loss

def detn_acc(input, target):
    _,c_t = target
    c_i = input[:,4:]
    return accuracy(c_i, c_t)

learn.crit = detn_loss
learn.metrics = [detn_acc, detn_l1]

# %%
'''#RuntimeError: size mismatch at model.py
error thrown during forward pass of the Flatten layer at end of 
Conv2d
BatchNorm2d
ReLU
Maxpool2d
Sequential multiple Conv2d(64,64)(64,64)(64,64)
Sequential multiple Conv2d()
Sequential multiple Conv2d()
Sequential set of 3, set of 2, set of 2 Conv2d(256,512)(512,512)(512,512) out_channels at end = 512
Flatten inFeatures=25088, outFeatures=256
>>Linear inFeatures=25088, outFeatures=4
see http://pytorch.org/docs/master/torch.html#torch.addmm 
- doing a matrix mult of input (nxm)=3x2048 by weight.t()=(mxp) ie 25088x4 when transposed
to get to work I changed Linear layer to 512x2x2 
'''
learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  72%|███████▏  | 905/1250 [01:00<00:22, 15.05it/s, loss=327]

# %%
lr=1e-3
#use_clr sets shed to use CircularLR
learn.fit(lrs=lr, n_cycle=1, cycle_len=3, use_clr=(32,5))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
#   8%|▊         | 102/1250 [00:09<01:42, 11.23it/s, loss=129]
#   8%|▊         | 105/1250 [00:09<01:42, 11.22it/s, loss=129]
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_monitor.py", line 63, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# epoch      trn_loss   val_loss   detn_acc   detn_l1
#     0      68.890352  59.010944  0.397314   7.774182
#     1      64.848237  55.573307  0.424471   7.706298
#     2      61.752429  54.409599  0.439846   7.673184
# [54.4096, 0.4398462460063898, 7.673184178507747]

# %%
learn.save('reg1_0')

# %%
layer_groups = learn.get_layer_groups()
print(f'{layer_groups}, {len(layer_groups)}')
# Out:
# [[Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False), BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True), ReLU(inplace), MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1), ceil_mode=False), Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (2): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   )
# ), Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (2): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (3): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   )
# )], [Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (downsample): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (2): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (3): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (4): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (5): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   )
# ), Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#   )
#   (2): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#   )
# )], Sequential(
#   (0): Sequential(
#     (0): Flatten(
#     )
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=2048, out_features=256, bias=True)
#     (4): ReLU()
#     (5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True)
#     (6): Dropout(p=0.5)
#     (7): Linear(in_features=256, out_features=204, bias=True)
#   )
# )], 3

# %%
#set to trainable the last two layer groups only 
learn.freeze_to(-2)

# %%
lrs = np.array([lr/100, lr/10, lr])

# %%
learn.lr_find(lrs/1000)
learn.sched.plot(0)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  76%|███████▌  | 948/1250 [01:24<00:26, 11.28it/s, loss=276]

# %%
learn.fit(lrs/5, n_cycle=1, cycle_len=5, use_clr=(32,10))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=5), HTML(value='')))
#   4%|▍         | 56/1250 [00:05<02:02,  9.72it/s, loss=79]
#   5%|▍         | 60/1250 [00:05<01:58, 10.00it/s, loss=79.2]
# Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_monitor.py", line 63, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/walle/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# epoch      trn_loss   val_loss   detn_acc   detn_l1
#     0      60.46626   51.502831  0.464956   7.541463
#     1      54.695998  48.033298  0.50005    7.377916
#     2      51.814506  46.098518  0.519269   7.319321
#     3      50.241291  45.332706  0.52531    7.276355
#     4      48.295412  44.950424  0.530851   7.263067
# [44.950424, 0.5308506389776357, 7.2630669057559665]

# %%
learn.save('reg1_1')

# %%
learn.load('reg1_1')

# %%
learn.unfreeze()

# %%
learn.fit(lrs=lrs/10, n_cycle=1, cycle_len=10, use_clr=(32, 10))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=10), HTML(value='')))
# epoch      trn_loss   val_loss   detn_acc   detn_l1
#     0      48.684466  44.874901  0.535194   7.268889
#     1      48.010522  43.958153  0.545078   7.23522
#     2      45.919402  43.493385  0.555112   7.208574
#     3      43.916255  43.014996  0.557208   7.187103
#     4      44.23758   42.827259  0.559056   7.163764
#     5      42.35106   42.389477  0.563898   7.131512
#     6      41.507608  42.133148  0.566793   7.130891
#     7      41.408105  42.132683  0.567043   7.127372
#     8      41.880396  42.051132  0.570188   7.126279
#     9      40.32023   42.012402  0.56859    7.131088
# [42.0124, 0.5685902555910544, 7.131087939198405]

# %%
learn.save('reg1')

# %%
learn.load('reg1')

# %%
preds = learn.predict()
x, _ = next(iter(md.val_dl))

# %%
fig, axes = plt.subplots(3, 4, figsize=(12,8))
for i, ax in enumerate(axes.flat):
    #val_ds is val_dl.dataset but val_ds.ds?, 
    #.denorm is a method in FilesDataset where we reverse the normalization done to a batch of images
    ima = md.val_ds.ds.denorm(to_np(x))[i]
    #module scipy.special._ufuncs: The expit function, also known as the logistic function, is defined as
    #expit(x) = 1/(1+exp(-x)). It is the inverse of the logit function
    print(f'preds[i][:4]: {preds[i][:4]}')
    bb = expit(preds[i][:4])*64
    print(f'bb: {bb}')
    #b = bb_hw(bb)
    c = np.argmax(preds[i][4:])
    ax = show_img(ima, ax=ax)
    draw_rect(ax, bb)
    draw_text(ax, bb[:2], md2.classes[c])
plt.tight_layout()
# Out:
# preds[i][:4]: [-0.94501 -1.1827   0.78633  0.71411]
# bb: [17.91295 15.01224 43.97069 42.96376]
# preds[i][:4]: [-4.35281 -2.80444  2.94967  2.48297]
# bb: [ 0.81325  3.65341 60.81585 59.0681 ]
# preds[i][:4]: [-0.72649 -0.36543  0.83318  1.21359]
# bb: [20.86181 26.21729 44.6097  49.33974]
# preds[i][:4]: [-0.77354 -0.77136  0.6407   0.54338]
# bb: [20.20564 20.2359  41.91428 40.48635]
# preds[i][:4]: [-2.75593 -2.3036   1.82893  2.01386]
# bb: [ 3.82416  5.81283 55.14457 56.46365]
# preds[i][:4]: [-3.76493 -2.49884  2.52322  1.96942]
# bb: [ 1.44925  4.86013 59.24825 56.16313]
# preds[i][:4]: [-3.26121 -2.80489  2.26165  2.22068]
# bb: [ 2.36328  3.65188 57.96165 57.73385]
# preds[i][:4]: [-2.08299 -1.95602  1.36291  1.35936]
# bb: [ 7.0887   7.92948 50.95885 50.92196]
# preds[i][:4]: [-1.22596 -1.70048  1.11549  1.26218]
# bb: [14.52095  9.88174 48.20169 49.88164]
# preds[i][:4]: [-3.61877 -2.5368   2.63369  2.42284]
# bb: [ 1.67139  4.69235 59.71191 58.78735]
# preds[i][:4]: [-1.98675 -2.0506   1.53471  1.75321]
# bb: [ 7.71848  7.29547 52.65245 54.55083]
# preds[i][:4]: [-2.1248  -2.26077  1.59618  2.193  ]
# bb: [ 6.8294   6.04318 53.21494 57.57564]
