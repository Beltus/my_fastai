# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# This file contains all the main external libs we'll use
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
PATH = '/mnt/samsung_1tb/Data/fastai/dogs_cats/data/redux/'
sz = 224

# %%
os.listdir(PATH)
# Out:
# ['results',
#  'test',
#  'submission1.csv',
#  'valid',
#  'models',
#  'sample_submission.csv',
#  'train',
#  'sample',
#  'tmp']

# %%
files = os.listdir(f'{PATH}valid/cats')[:5]

# %%
#img = plt.imread(f'{PATH}valid/cats/{files[0]}')

# %%
#plt.imshow(img)
#plt.show()
#plt.savefig('temp.png')

# %%
f_model = resnet34
data = ImageClassifierData.from_paths(PATH, tfms=tfms_from_model(f_model, sz), test_name='test')
learn = ConvLearner.pretrained(f_model, data, precompute=True)
learn.fit(lrs = 0.01, n_cycle = 2)
# Out:
# 100%|██████████| 32/32 [00:03<00:00,  9.45it/s]
# HBox(children=(IntProgress(value=0, description='Epoch', max=2), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.047723   0.026293   0.990723
#     1      0.039478   0.025148   0.991211
# [0.025147708, 0.9912109375]

# %%
data.val_y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
data.classes
# Out:
# ['cats', 'dogs']

# %%
log_preds = learn.predict()
log_preds.shape
# Out:
# (2000, 2)

# %%
log_preds[:2]
# Out:
# array([[ -0.00002, -11.04728],
#        [ -0.00068,  -7.29005]], dtype=float32)

# %%
preds = np.argmax(log_preds, axis=1)
dog_probs = np.exp(log_preds[:,1])

# %%
def rand_by_mask(mask): 
    #(a, size, replace)
    #generate random sample from a, size is output elements
    val = np.random.choice(np.where(mask)[0], 4, replace=False)
    return val
    
def rand_by_correct(is_correct): 
    correct_flag = rand_by_mask((preds == data.val_y)==is_correct)
    return correct_flag

# %%
def plots(images, figsize=(12, 6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(images)):
        sp = f.add_subplot(rows, len(images)//rows, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(images[i])

# %%
def load_image_id(ds, idx):
    return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(idxs, title):
    imgs = [load_image_id(data.val_ds, x) for x in idxs]
    title_probs = [dog_probs[x] for x in idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8))

# %%
plot_val_with_title(rand_by_correct(True), "Correct")
# Out:
# Correct

# %%
plot_val_with_title(rand_by_correct(False), "Inorrect")
# Out:
# Inorrect

# %%
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[idxs])[:4]]

# %%
def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask((preds == data.val_y)==is_correct & (data.val_y == y), mult)

# %%
#### Learning Rate

# %%
#create a new learner
learn = ConvLearner.pretrained(f_model, data, precompute=True)

# %%
#defaults are start_lr=1e-5, end_lr=10
lrf = learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  84%|████████▍ | 304/360 [00:02<00:00, 128.69it/s, loss=0.456]

# %%
learn.sched.plot_lr()

# %%
learn.sched.plot()

# %%
#### Augmentation

# %%
tfms = tfms_from_model(f_model, sz, aug_tfms=transforms_side_on, max_zoom=1.1)

# %%
def get_augs():
    batch_size = 2
    data = ImageClassifierData.from_paths(PATH, bs=batch_size, tfms=tfms, num_workers=1)
    x, y = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[1]

# %%
images = np.stack([get_augs() for i in range(6)])
plots(images, rows=2)

# %%
#### create a new data object, that includes augmentation in transforms

# %%
data = ImageClassifierData.from_paths(PATH, tfms=tfms, test_name='test')
learn = ConvLearner.pretrained(f_model, data, precompute=True)

# %%
learn.fit(lrs=1e-2,n_cycle=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.046402   0.025329   0.989746
# [0.025329057, 0.98974609375]

# %%
#### turn off precompute so can update weights of last layer
learn.precompute = False
learn.fit(lrs=1e-2, n_cycle=3, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.043977   0.021476   0.991699
#     1      0.04568    0.023984   0.991699
#     2      0.049843   0.022908   0.991699
# [0.022908285, 0.99169921875]

# %%
#cycle_len: number of epochs between resetting learning rate
#n_cycle: number times learning rate is reset
learn.sched.plot_lr()

# %%
learn.save('224_lastlayer')
learn.load('224_lastlayer')

# %%
#### Annealing

# %%
learn.unfreeze()

# %%
#### Only want to tune the earlier layers

# %%
#I presume layers are divided by 3 when this is applied
lrs=np.array([1e-4,1e-3,1e-2])

# %%
#cycle_mult=2 doubles the number of iterations each cycle
learn.fit(lrs, n_cycle=3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.059531   0.028938   0.98877
#     1      0.040871   0.025821   0.991211
#     2      0.030737   0.02389    0.991211
#     3      0.02622    0.023525   0.992676
#     4      0.029138   0.024089   0.992676
#     5      0.024227   0.024938   0.992676
#     6      0.016597   0.024867   0.992676
# [0.024867326, 0.99267578125]

# %%
learn.sched.plot_lr()

# %%
learn.save('224_all')

# %%
learn.load('224_all')

# %%
#Test (inference) time augmentation - predictions on validation set images and randomly augmented versions, takes average prediction of these

# %%
log_preds, y = learn.TTA()

# %%
probs = np.mean(np.exp(log_preds), 0)
probs
# Out:
# array([[0.99998, 0.00002],
#        [0.96214, 0.03786],
#        [0.99668, 0.00332],
#        ...,
#        [0.00023, 0.99977],
#        [0.00002, 0.99998],
#        [0.00032, 0.99968]], dtype=float32)

# %%
accuracy_np(probs, y)
# Out:
# 0.991

# %%
#confusion matrix

# %%
metrics.log_loss(y, probs)
# Out:
# 0.018196928150648623

# %%
#TODO confusion matrix section
preds = np.argmax(probs, axis=1)
probs = probs[:,1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y, preds)

# %%
plot_confusion_matrix(cm, data.classes)
# Out:
# [[ 973    6]
#  [  12 1009]]

# %%
plot_val_with_title(most_by_correct(1, False),"Most incorrect Dogs")
plt.show()
plt.savefig('temp.png')
# Out:
# Most incorrect Dogs

# %%
#### submission

# %%
log_test_preds, y = learn.TTA(is_test=True)
test_probs = np.mean(np.exp(log_test_preds), 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-8dc12f1abb17> in <module>()
# ----> 1 log_test_preds, y = learn.TTA(is_test=True)
#       2 test_probs = np.mean(np.exp(log_test_preds),0)
#
# /mnt/963GB/Data/Python/Courses/fastai/fastai/courses/dl1/fastai/learner.py in TTA(self, n_aug, is_test)
#     290         dl1 = self.data.test_dl     if is_test else self.data.val_dl
#     291         dl2 = self.data.test_aug_dl if is_test else self.data.aug_dl
# --> 292         preds1,targs = predict_with_targs(self.model, dl1)
#     293         preds1 = [preds1]*math.ceil(n_aug/4)
#     294         preds2 = [predict_with_targs(self.model, dl2)[0] for i in tqdm(range(n_aug), leave=False)]
#
# /mnt/963GB/Data/Python/Courses/fastai/fastai/courses/dl1/fastai/model.py in predict_with_targs(m, dl)
#     150
#     151 def predict_with_targs(m, dl):
# --> 152     preda,targa = predict_with_targs_(m, dl)
#     153     return to_np(torch.cat(preda)), to_np(torch.cat(targa))
#     154
#
# /mnt/963GB/Data/Python/Courses/fastai/fastai/courses/dl1/fastai/model.py in predict_with_targs_(m, dl)
#     146     if hasattr(m, 'reset'): m.reset()
#     147     res = []
# --> 148     for *x,y in iter(dl): res.append([get_prediction(m(*VV(x))),y])
#     149     return zip(*res)
#     150
#
# TypeError: 'NoneType' object is not iterable

# %%
print(test_probs.shape)
is_dog = test_probs[:, 1]
print(f'First 4 preds: {is_dog[:4]}')

# %%
is_dog = is_dog.clip(min=0.01, max=0.99)
df = pd.DataFrame(is_dog, columns=['label'])
df.insert(0, 'id', [o[5:-4] for o in data.test_ds.fnames])
df.head()

# %%
SUBM = f'{PATH}submission/'
os.makedirs(SUBM, exist_ok=True)
df.to_csv(f'{SUBM}subm.gz', compression='gzip', index=False)

# %%
### gives a kaggle score of 0.04775 (46th place), (compared to 1.1 last year)
